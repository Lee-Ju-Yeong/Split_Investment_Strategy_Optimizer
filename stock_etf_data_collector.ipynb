# %% [markdown]
# # 주식 및 ETF 데이터 수집

# %%
# pip install beautifulsoup4 pandas openpyxl selenium webdriver-manager pykrx sqlalchemy pymysql

# %%
# pip install pymysql
# Out:
# Requirement already satisfied: pymysql in e:\아경\ai\python38\lib\site-packages (1.1.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 24.0 is available.
# You should consider upgrading via the 'e:\아경\AI\Python38\python.exe -m pip install --upgrade pip' command.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time
from pykrx import stock
import datetime
import os
from sqlalchemy import create_engine
import pymysql
import numpy as np
import configparser



# 설정 파일 읽기
config = configparser.ConfigParser()
config.read('config.ini')

username = config['mysql']['username']
password = config['mysql']['password']
host = config['mysql']['host']
database = config['mysql']['database']

conn = pymysql.connect(host=host, user=username, password=password, db=database, charset='utf8')
cur = conn.cursor()

# %%
# 테이블 생성 함수
def create_tables():
    cur.execute('''
    CREATE TABLE IF NOT EXISTS stock_data (
        ticker VARCHAR(10),
        name VARCHAR(100),
        date DATE,
        open FLOAT,
        high FLOAT,
        low FLOAT,
        close FLOAT,
        volume BIGINT,
        value BIGINT,
        market_cap BIGINT,
        shares_outstanding BIGINT,
        PER FLOAT,
        PBR FLOAT,
        dividend FLOAT,
        BPS FLOAT,
        EPS FLOAT,
        DPS FLOAT,
        normalized_value FLOAT,
        PRIMARY KEY (ticker, date)
    )
    ''')
    cur.execute('''
    CREATE TABLE IF NOT EXISTS ticker_list (
        ticker VARCHAR(10) PRIMARY KEY,
        market VARCHAR(10),
        name VARCHAR(100),
        last_updated DATE,
        is_delisted BOOLEAN DEFAULT FALSE
    )
    ''')
    cur.execute('''
    CREATE TABLE IF NOT EXISTS ticker_status (
        ticker VARCHAR(10) PRIMARY KEY,
        status VARCHAR(20)
    )
    ''')
create_tables()

# %%
# 모든 티커 리스트를 저장할 집합
all_tickers = set()

# 시작 날짜와 현재 날짜 설정
start_date = '19950102' # 이 시기부터 ticker list를 제공
end_date = datetime.datetime.now().strftime('%Y%m%d')

# 모든 날짜에 대해 티커 리스트 가져오기
current_date = datetime.datetime.strptime(start_date, '%Y%m%d')
while current_date.strftime('%Y%m%d') <= end_date:
    date_str = current_date.strftime('%Y%m%d')
    try:
        tickers_kosdaq = stock.get_market_ticker_list(date_str, market='KOSDAQ')
        tickers_kospi = stock.get_market_ticker_list(date_str, market='KOSPI')
        all_tickers.update(tickers_kosdaq)
        all_tickers.update(tickers_kospi)
        print(len(all_tickers),f'{date_str}')
        time.sleep(0.8)
    except Exception as e:
        print(f"Error on date {date_str}: {e}")
    current_date += datetime.timedelta(days=180)  # 180일 단위로 진행
    
# 티커 목록을 MySQL에 저장
for ticker in all_tickers:
    market = 'KOSDAQ' if ticker in tickers_kosdaq else 'KOSPI'
    name = stock.get_market_ticker_name(ticker)
    cur.execute('''
    INSERT INTO ticker_list (ticker, market, name) VALUES (%s, %s, %s)
    ON DUPLICATE KEY UPDATE market=VALUES(market), name=VALUES(name)
    ''', (ticker, market, name))
    # cur.execute('''
    # INSERT INTO ticker_status (ticker, status) VALUES (%s, 'pending')
    # ON DUPLICATE KEY UPDATE status=VALUES(status)
    # ''', (ticker,))  #1회 실행
    conn.commit()

cur.close()
conn.close()
print("모든 티커 목록이 성공적으로 저장되었습니다.")
# Out:
# 0 19950102
# 956 19950701
# 1132 19951228
# 1190 19960625
# 1758 19961222
# 1827 19970620
# 1906 19971217
# 1930 19980615
# 1941 19981212
# 2003 19990610
# 2117 19991207
# 2298 20000604
# 2440 20001201
# 2525 20010530
# 2638 20011126
# 2773 20020525
# 2848 20021121
# 2895 20030520
# 2944 20031116
# 2983 20040514
# 3016 20041110
# 3061 20050509
# 3121 20051105
# 3164 20060504
# 3214 20061031
# 3257 20070429
# 3322 20071026
# 3361 20080423
# 3404 20081020
# 3428 20090418
# 3467 20091015
# 3519 20100413
# 3571 20101010
# 3625 20110408
# 3664 20111005
# 3702 20120402
# 3720 20120929
# 3740 20130328
# 3758 20130924
# 3785 20140323
# 3807 20140919
# 3865 20150318
# 3932 20150914
# 4002 20160312
# 4034 20160908
# 4087 20170307
# 4137 20170903
# 4189 20180302
# 4227 20180829
# 4292 20190225
# 4338 20190824
# 4406 20200220
# 4450 20200818
# 4517 20210214
# 4573 20210813
# 4639 20220209
# 4693 20220808
# 4762 20230204
# 4832 20230803
# 4908 20240130
# 모든 티커 목록이 성공적으로 저장되었습니다.

# %% [markdown]
# ## Step 2: 데이터 갱신 및 새로운 티커 추가 (중단 후 재시작 가능)
# * 한번 실행한 경우 몇 거래일 뒤에 다시 실행해야 오류가 발생하지 않음

# %%
import datetime
import pymysql
import configparser
from pykrx import stock
import numpy as np

# 설정 파일 읽기
config = configparser.ConfigParser()
config.read('config.ini')

username = config['mysql']['username']
password = config['mysql']['password']
host = config['mysql']['host']
database = config['mysql']['database']

conn = pymysql.connect(host=host, user=username, password=password, db=database, charset='utf8')
cur = conn.cursor()

# 조건 설정
per_threshold = 10
pbr_threshold = 1
div_threshold = 3.5  # 기준금리 참조

# 현재 날짜 기준으로 최근 월 종목 리스트 수집
current_date = datetime.datetime.now()
last_month_str = current_date.strftime("%Y%m") + '01'

# 데이터베이스에서 모든 티커 가져오기
cur.execute("SELECT ticker FROM ticker_list")
all_tickers = [row[0] for row in cur.fetchall()]

# 각 티커에 대한 처리
for ticker in all_tickers:
    # 이미 처리된 티커는 스킵
    cur.execute(f"SELECT status FROM ticker_status WHERE ticker = '{ticker}'")
    status = cur.fetchone()
    if status and status[0] == 'completed':
        continue
    
     # 티커의 끝자리가 0이 아닌 경우 스킵
    if ticker[-1] != '0':
        print(f'{ticker} skipped because it does not end with 0')
        continue    
    
    # 데이터베이스에서 마지막 날짜 확인
    cur.execute(f"SELECT MAX(date) FROM stock_data WHERE ticker = '{ticker}'")
    last_date = cur.fetchone()[0]
    # 마지막 날짜가 현재 날짜와 7일 이하로 차이나는 경우 continue
    if last_date: # 이미 저장된 데이터가 있다면
        last_recorded_date = pd.to_datetime(last_date)
        if (current_date - last_recorded_date).days <= 28:
            print(f'{ticker} already done')
            continue
    # 새 데이터를 가져옴
    if last_date:
        start_date = (last_date + datetime.timedelta(days=1)).strftime("%Y%m%d")
    else:
        start_date = "19800102"

    end_date = current_date.strftime("%Y%m%d")
    time.sleep(3)
    df2 = stock.get_market_fundamental(start_date, end_date, ticker)


    if df2.empty or 'PER' not in df2.columns:
        cur.execute(f"UPDATE ticker_status SET status = 'completed' WHERE ticker = '{ticker}'")
        conn.commit()
        print(f'{ticker} no.2 pass condition')
        time.sleep(3)
        continue

    # 조건 확인
    if ('PER' in df2.columns and 'PBR' in df2.columns and 'DIV' in df2.columns):
        condition = (df2['PER'] > 0) & (df2['PER'] <= per_threshold) & \
                    (df2['PBR'] > 0) & (df2['PBR'] <= pbr_threshold) & \
                    (df2['DIV'] >= div_threshold)
        if not condition.any() and last_date is None:  #조건을 만족하지 않거나 새로운데이터가 없으면 해당 종목은 종료(completed)
            cur.execute(f"UPDATE ticker_status SET status = 'completed' WHERE ticker = '{ticker}'")
            conn.commit()
            print(f'{ticker} no.3 pass condition')
            time.sleep(5.1)  
            continue  # 조건을 만족하지 않으면 다음 티커로 넘어감
        
    else:
        cur.execute(f"UPDATE ticker_status SET status = 'completed' WHERE ticker = '{ticker}'")
        conn.commit()
        print(f'{ticker} no.4 pass condition')
        continue  # 필요한 컬럼이 없으면 넘어감
    time.sleep(5.2)     
    df1 = stock.get_market_ohlcv(start_date, end_date, ticker)
    

    if df1.empty:
        cur.execute(f"UPDATE ticker_status SET status = 'completed' WHERE ticker = '{ticker}'")
        conn.commit()
        print(f'{ticker} no.5 pass condition')
        continue

    # '고가' 컬럼이 있는지 확인
    if '고가' not in df1.columns:
        cur.execute(f"UPDATE ticker_status SET status = 'completed' WHERE ticker = '{ticker}'")
        conn.commit()
        print(f'{ticker} no.6 pass condition')
        continue
    time.sleep(5)   
    df3 = stock.get_market_cap(start_date, end_date, ticker)
    
    
    df1.reset_index(inplace=True)
    df2.reset_index(inplace=True)
    df3.reset_index(inplace=True)
    # 컬럼명 통일
    df1.rename(columns={
        '날짜': 'date',
        '시가': 'open',
        '고가': 'high',
        '저가': 'low',
        '종가': 'close',
        '거래량': 'volume',
        
    }, inplace=True)

    df2.rename(columns={
        '날짜': 'date',
        'PER': 'PER',
        'PBR': 'PBR',
        'DIV': 'dividend',
        'BPS': 'BPS',
        'EPS': 'EPS',
        'DPS': 'DPS'
    }, inplace=True)

    df3.rename(columns={
        '날짜': 'date',
        '시가총액': 'market_cap',
        '상장주식수': 'shares_outstanding',
        '거래대금': 'value',
        '거래량': 'volume'
        
    }, inplace=True)

    
     # 날짜 기준으로 결합하고 중복된 열 제거
    merged_df = pd.merge(df1, df2, on='date', how='outer', suffixes=('', '_duplicate'))
    merged_df = pd.merge(merged_df, df3, on='date', how='outer', suffixes=('', '_duplicate'))
    
    # 중복된 열 제거
    for column in merged_df.columns:
        if 'duplicate' in column:
            base_column = column.replace('_duplicate', '')
            if base_column in merged_df.columns:
                merged_df.drop(column, axis=1, inplace=True)
    
    # 필요한 열만 남기기
    merged_df = merged_df[['date', 'open', 'high', 'low', 'close', 'volume', 'value', 'market_cap', 'shares_outstanding', 'PER', 'PBR', 'dividend', 'BPS', 'EPS', 'DPS']]
  
    # NaN 값을 None으로 변환 (개별적으로 처리)
    merged_df = merged_df.replace({np.nan: None})

    
    name = stock.get_market_ticker_name(ticker)
    merged_df['ticker'] = ticker
    merged_df['name'] = name
    merged_df.set_index('date', inplace=True)
    

    # 기존 데이터를 가져와서 새로운 데이터와 결합
    if last_date:
        cur.execute(f"SELECT * FROM stock_data WHERE ticker = '{ticker}' AND date <= '{last_date}'")
        existing_data = pd.DataFrame(cur.fetchall(), columns=['ticker', 'name', 'date', 'open', 'high', 'low', 'close', 'volume', 'value', 'market_cap', 'shares_outstanding', 'PER', 'PBR', 'dividend', 'BPS', 'EPS', 'DPS','normalized_value'])
        existing_data['date'] = pd.to_datetime(existing_data['date'])
        
        existing_data.set_index('date', inplace=True)
        # merged_df.set_index('date', inplace=True)
        
        combined_df = pd.concat([existing_data, merged_df], axis=0, join='outer')
          # 여기서 결합 전에 각 데이터프레임 확인

        
    else: # 기존데이터가 없으면 로드된 세 DF만 결합
        combined_df = merged_df
    # print(combined_df)
    


    # print(combined_df.columns)
    # 노멀라이즈드 값 계산
    combined_df['normalized_value'] = (combined_df['close'] - combined_df['close'].rolling(window=252*5, min_periods=252).min()) / \
                                      (combined_df['close'].rolling(window=252*5, min_periods=252).max() - combined_df['close'].rolling(window=252*5, min_periods=252).min()) * 100

    combined_df.reset_index(inplace=True)
    
    combined_df = combined_df.replace({np.nan: None})
    
    time.sleep(0.4)  
    # 데이터베이스에 저장
    for _, row in combined_df.iterrows():
        sql = '''
        INSERT INTO stock_data (ticker, name, date, open, high, low, close, volume, value, market_cap, shares_outstanding, PER, PBR, dividend, BPS, EPS, DPS, normalized_value)
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
        ON DUPLICATE KEY UPDATE
            open=VALUES(open),
            high=VALUES(high),
            low=VALUES(low),
            close=VALUES(close),
            volume=VALUES(volume),
            value=VALUES(value),
            market_cap=VALUES(market_cap),
            shares_outstanding=VALUES(shares_outstanding),
            PER=VALUES(PER),
            PBR=VALUES(PBR),
            dividend=VALUES(dividend),
            BPS=VALUES(BPS),
            EPS=VALUES(EPS),
            DPS=VALUES(DPS),
            normalized_value=VALUES(normalized_value)
        '''
        cur.execute(sql, (
            row['ticker'],
            row['name'],
            row['date'].strftime('%Y-%m-%d') if row['date'] else None,
            row['open'],
            row['high'],
            row['low'],
            row['close'],
            int(row['volume']) if row['volume'] is not None else None,
            int(row['value']) if row['value'] is not None else None,
            int(row['market_cap']) if row['market_cap'] is not None else None,
            int(row['shares_outstanding']) if row['shares_outstanding'] is not None else None,
            row['PER'],
            row['PBR'],
            row['dividend'],
            row['BPS'],
            row['EPS'],
            row['DPS'],
            row['normalized_value']
        ))

    conn.commit()
     # 최근 60일 동안 데이터가 있는지 확인
    last_recorded_date = pd.to_datetime(combined_df['date']).max()
    if (current_date - last_recorded_date).days > 60:
        print(current_date - last_recorded_date,current_date,last_recorded_date)
        cur.execute(f"UPDATE ticker_status SET status = 'completed' WHERE ticker = '{ticker}'")
        conn.commit()
    print(f"{ticker} 데이터베이스에 저장 완료")
    time.sleep(5)


cur.close()
conn.close()
print("모든 데이터가 성공적으로 저장되었습니다.")
# Out:
# 000020 already done
# 000070 already done
# 000140 already done
# 000150 already done
# 000210 already done
# 000220 already done
# 000230 already done
# 000240 already done
# 000250 already done
# 000270 already done
# 000320 already done
# 000370 already done
# 000390 already done
# 000400 already done
# 000430 already done
# 000440 already done
# 000480 already done
# 000490 already done
# 000500 already done
# 000520 already done
# 000590 already done
# 000640 already done
# 000700 already done
# 000721 skipped because it does not end with 0
# 000725 skipped because it does not end with 0
# 000726 skipped because it does not end with 0
# 000791 skipped because it does not end with 0
# 000794 skipped because it does not end with 0
# 000801 skipped because it does not end with 0
# 000805 skipped because it does not end with 0
# 000810 already done
# 000815 skipped because it does not end with 0
# 000831 skipped because it does not end with 0
# 000835 skipped because it does not end with 0
# 000850 already done
# 000860 already done
# 000880 already done
# 000881 skipped because it does not end with 0
# 000885 skipped because it does not end with 0
# 000887 skipped because it does not end with 0
# 00088K skipped because it does not end with 0
# 000895 skipped because it does not end with 0
# 000901 skipped because it does not end with 0
# 000905 skipped because it does not end with 0
# 000910 already done
# 000911 skipped because it does not end with 0
# 000912 skipped because it does not end with 0
# 000931 skipped because it does not end with 0
# 000950 already done
# 000970 already done
# 000981 skipped because it does not end with 0
# 000985 skipped because it does not end with 0
# 000990 already done
# 000995 skipped because it does not end with 0
# 000997 skipped because it does not end with 0
# 001020 already done
# 001035 skipped because it does not end with 0
# 001040 already done
# 001045 skipped because it does not end with 0
# 001047 skipped because it does not end with 0
# 001049 skipped because it does not end with 0
# 00104K skipped because it does not end with 0
# 001060 already done
# 001061 skipped because it does not end with 0
# 001065 skipped because it does not end with 0
# 001067 skipped because it does not end with 0
# 001080 already done
# 001095 skipped because it does not end with 0
# 001111 skipped because it does not end with 0
# 001120 already done
# 001121 skipped because it does not end with 0
# 001130 already done
# 001155 skipped because it does not end with 0
# 001171 skipped because it does not end with 0
# 001191 skipped because it does not end with 0
# 001192 skipped because it does not end with 0
# 001200 already done
# 001211 skipped because it does not end with 0
# 001230 already done
# 001265 skipped because it does not end with 0
# 001270 already done
# 001275 skipped because it does not end with 0
# 001290 already done
# 001295 skipped because it does not end with 0
# 001301 skipped because it does not end with 0
# 001311 skipped because it does not end with 0
# 001340 already done
# 001361 skipped because it does not end with 0
# 001362 skipped because it does not end with 0
# 001371 skipped because it does not end with 0
# 001375 skipped because it does not end with 0
# 001381 skipped because it does not end with 0
# 001385 skipped because it does not end with 0
# 001390 already done
# 001391 skipped because it does not end with 0
# 001420 already done
# 001430 already done
# 001431 skipped because it does not end with 0
# 001440 already done
# 001450 already done
# 001465 skipped because it does not end with 0
# 001470 already done
# 001471 skipped because it does not end with 0
# 001500 already done
# 001501 skipped because it does not end with 0
# 001515 skipped because it does not end with 0
# 001520 already done
# 001525 skipped because it does not end with 0
# 001527 skipped because it does not end with 0
# 001529 skipped because it does not end with 0
# 001530 already done
# 001560 already done
# 001570 already done
# 001615 skipped because it does not end with 0
# 001620 already done
# 001630 already done
# 001675 skipped because it does not end with 0
# 001680 already done
# 001681 skipped because it does not end with 0
# 001685 skipped because it does not end with 0
# 001686 skipped because it does not end with 0
# 001687 skipped because it does not end with 0
# 001689 skipped because it does not end with 0
# 001691 skipped because it does not end with 0
# 001695 skipped because it does not end with 0
# 001697 skipped because it does not end with 0
# 001720 already done
# 001725 skipped because it does not end with 0
# 001741 skipped because it does not end with 0
# 001745 skipped because it does not end with 0
# 001750 already done
# 001755 skipped because it does not end with 0
# 001770 already done
# 001785 skipped because it does not end with 0
# 001787 skipped because it does not end with 0
# 001790 already done
# 001791 skipped because it does not end with 0
# 001795 skipped because it does not end with 0
# 001797 skipped because it does not end with 0
# 001799 skipped because it does not end with 0
# 001800 already done
# 001810 already done
# 001821 skipped because it does not end with 0
# 001831 skipped because it does not end with 0
# 001835 skipped because it does not end with 0
# 001837 skipped because it does not end with 0
# 001940 already done
# 001955 skipped because it does not end with 0
# 001971 skipped because it does not end with 0
# 001975 skipped because it does not end with 0
# 002005 skipped because it does not end with 0
# 002011 skipped because it does not end with 0
# 002015 skipped because it does not end with 0
# 002020 already done
# 002021 skipped because it does not end with 0
# 002025 skipped because it does not end with 0
# 002027 skipped because it does not end with 0
# 002030 already done
# 002031 skipped because it does not end with 0
# 002055 skipped because it does not end with 0
# 002070 already done
# 002100 already done
# 002101 skipped because it does not end with 0
# 002105 skipped because it does not end with 0
# 002140 already done
# 002170 already done
# 002181 skipped because it does not end with 0
# 002200 already done
# 002201 skipped because it does not end with 0
# 002220 already done
# 002230 already done
# 002240 already done
# 002255 skipped because it does not end with 0
# 002257 skipped because it does not end with 0
# 002290 already done
# 002301 skipped because it does not end with 0
# 002310 already done
# 002311 skipped because it does not end with 0
# 002320 already done
# 002341 skipped because it does not end with 0
# 002350 already done
# 002354 skipped because it does not end with 0
# 002355 skipped because it does not end with 0
# 002357 skipped because it does not end with 0
# 002365 skipped because it does not end with 0
# 002380 already done
# 002390 already done
# 002410 already done
# 002411 skipped because it does not end with 0
# 002420 already done
# 002445 skipped because it does not end with 0
# 002450 already done
# 002451 skipped because it does not end with 0
# 002455 skipped because it does not end with 0
# 002460 already done
# 002461 skipped because it does not end with 0
# 002471 skipped because it does not end with 0
# 002531 skipped because it does not end with 0
# 002535 skipped because it does not end with 0
# 002581 skipped because it does not end with 0
# 002585 skipped because it does not end with 0
# 002600 already done
# 002611 skipped because it does not end with 0
# 002615 skipped because it does not end with 0
# 002620 already done
# 002631 skipped because it does not end with 0
# 002671 skipped because it does not end with 0
# 002680 already done
# 002710 already done
# 002720 already done
# 002735 skipped because it does not end with 0
# 002741 skipped because it does not end with 0
# 002742 skipped because it does not end with 0
# 002745 skipped because it does not end with 0
# 002746 skipped because it does not end with 0
# 002785 skipped because it does not end with 0
# 002787 skipped because it does not end with 0
# 002795 skipped because it does not end with 0
# 002797 skipped because it does not end with 0
# 00279K skipped because it does not end with 0
# 002810 already done
# 002814 skipped because it does not end with 0
# 002820 already done
# 002840 already done
# 002851 skipped because it does not end with 0
# 002855 skipped because it does not end with 0
# 002857 skipped because it does not end with 0
# 002870 already done
# 002900 already done
# 002920 already done
# 002935 skipped because it does not end with 0
# 002951 skipped because it does not end with 0
# 002955 skipped because it does not end with 0
# 002957 skipped because it does not end with 0
# 002960 already done
# 002990 already done
# 002995 skipped because it does not end with 0
# 003010 already done
# 003030 already done
# 003031 skipped because it does not end with 0
# 003051 skipped because it does not end with 0
# 003070 already done
# 003071 skipped because it does not end with 0
# 003075 skipped because it does not end with 0
# 003079 skipped because it does not end with 0
# 003080 already done
# 003081 skipped because it does not end with 0
# 003082 skipped because it does not end with 0
# 003090 already done
# 003091 skipped because it does not end with 0
# 003092 skipped because it does not end with 0
# 003100 already done
# 003120 already done
# 003160 already done
# 003161 skipped because it does not end with 0
# 003200 already done
# 003220 already done
# 003280 already done
# 003291 skipped because it does not end with 0
# 003300 already done
# 003335 skipped because it does not end with 0
# 003415 skipped because it does not end with 0
# 003417 skipped because it does not end with 0
# 003419 skipped because it does not end with 0
# 00341A skipped because it does not end with 0
# 00341D skipped because it does not end with 0
# 003451 skipped because it does not end with 0
# 003457 skipped because it does not end with 0
# 003460 already done
# 003465 skipped because it does not end with 0
# 003470 already done
# 003475 skipped because it does not end with 0
# 003480 already done
# 003481 skipped because it does not end with 0
# 003490 already done
# 003495 skipped because it does not end with 0
# 003497 skipped because it does not end with 0
# 003530 already done
# 003535 skipped because it does not end with 0
# 003540 already done
# 003545 skipped because it does not end with 0
# 003547 skipped because it does not end with 0
# 003550 already done
# 003551 skipped because it does not end with 0
# 003555 skipped because it does not end with 0
# 003561 skipped because it does not end with 0
# 003570 already done
# 003595 skipped because it does not end with 0
# 003601 skipped because it does not end with 0
# 003605 skipped because it does not end with 0
# 003610 already done
# 003621 skipped because it does not end with 0
# 003650 already done
# 003665 skipped because it does not end with 0
# 003690 already done
# 003691 skipped because it does not end with 0
# 003701 skipped because it does not end with 0
# 003720 already done
# 003780 already done
# 003800 already done
# 003850 already done
# 003905 skipped because it does not end with 0
# 003925 skipped because it does not end with 0
# 003931 skipped because it does not end with 0
# 003941 skipped because it does not end with 0
# 003945 skipped because it does not end with 0
# 003946 skipped because it does not end with 0
# 003965 skipped because it does not end with 0
# 003967 skipped because it does not end with 0
# 003971 skipped because it does not end with 0
# 003975 skipped because it does not end with 0
# 003985 skipped because it does not end with 0
# 004000 already done
# 004001 skipped because it does not end with 0
# 004011 skipped because it does not end with 0
# 004020 already done
# 004021 skipped because it does not end with 0
# 004025 skipped because it does not end with 0
# 004061 skipped because it does not end with 0
# 004080 already done
# 004090 already done
# 004105 skipped because it does not end with 0
# 004111 skipped because it does not end with 0
# 004135 skipped because it does not end with 0
# 004137 skipped because it does not end with 0
# 004141 skipped because it does not end with 0
# 004145 skipped because it does not end with 0
# 004147 skipped because it does not end with 0
# 004149 skipped because it does not end with 0
# 004150 already done
# 004151 skipped because it does not end with 0
# 004155 skipped because it does not end with 0
# 004171 skipped because it does not end with 0
# 004175 skipped because it does not end with 0
# 004250 already done
# 004255 skipped because it does not end with 0
# 004270 already done
# 004295 skipped because it does not end with 0
# 004310 already done
# 004321 skipped because it does not end with 0
# 004325 skipped because it does not end with 0
# 004360 already done
# 004365 skipped because it does not end with 0
# 004367 skipped because it does not end with 0
# 004380 already done
# 004411 skipped because it does not end with 0
# 004415 skipped because it does not end with 0
# 004430 already done
# 004431 skipped because it does not end with 0
# 004432 skipped because it does not end with 0
# 004440 already done
# 004450 already done
# 004465 skipped because it does not end with 0
# 004481 skipped because it does not end with 0
# 004490 already done
# 004511 skipped because it does not end with 0
# 004545 skipped because it does not end with 0
# 004551 skipped because it does not end with 0
# 004555 skipped because it does not end with 0
# 004560 already done
# 004565 skipped because it does not end with 0
# 004590 already done
# 004605 skipped because it does not end with 0
# 004621 skipped because it does not end with 0
# 004650 already done
# 004690 already done
# 004691 skipped because it does not end with 0
# 004692 skipped because it does not end with 0
# 004700 already done
# 004701 skipped because it does not end with 0
# 004711 skipped because it does not end with 0
# 004735 skipped because it does not end with 0
# 004770 already done
# 004791 skipped because it does not end with 0
# 004800 already done
# 004831 skipped because it does not end with 0
# 004835 skipped because it does not end with 0
# 004837 skipped because it does not end with 0
# 004840 already done
# 004871 skipped because it does not end with 0
# 004890 already done
# 004910 already done
# 004941 skipped because it does not end with 0
# 004945 skipped because it does not end with 0
# 004947 skipped because it does not end with 0
# 004960 already done
# 004965 skipped because it does not end with 0
# 004970 already done
# 004980 already done
# 004985 skipped because it does not end with 0
# 004987 skipped because it does not end with 0
# 004989 skipped because it does not end with 0
# 004990 already done
# 00499K skipped because it does not end with 0
# 005010 already done
# 005011 skipped because it does not end with 0
# 005015 skipped because it does not end with 0
# 005030 already done
# 005061 skipped because it does not end with 0
# 005090 already done
# 005101 skipped because it does not end with 0
# 005105 skipped because it does not end with 0
# 005111 skipped because it does not end with 0
# 005114 skipped because it does not end with 0
# 005117 skipped because it does not end with 0
# 005160 already done
# 005180 already done
# 005181 skipped because it does not end with 0
# 005250 already done
# 005255 skipped because it does not end with 0
# 005257 skipped because it does not end with 0
# 005271 skipped because it does not end with 0
# 005305 skipped because it does not end with 0
# 005320 already done
# 005321 skipped because it does not end with 0
# 005360 already done
# 005371 skipped because it does not end with 0
# 005380 already done
# 005385 skipped because it does not end with 0
# 005386 skipped because it does not end with 0
# 005387 skipped because it does not end with 0
# 005389 skipped because it does not end with 0
# 005411 skipped because it does not end with 0
# 005430 already done
# 005440 already done
# 005441 skipped because it does not end with 0
# 005444 skipped because it does not end with 0
# 005447 skipped because it does not end with 0
# 005490 already done
# 005500 already done
# 005561 skipped because it does not end with 0
# 005605 skipped because it does not end with 0
# 005610 already done
# 005611 skipped because it does not end with 0
# 005621 skipped because it does not end with 0
# 005664 skipped because it does not end with 0
# 005667 skipped because it does not end with 0
# 005670 already done
# 005671 skipped because it does not end with 0
# 005672 skipped because it does not end with 0
# 005680 already done
# 005710 already done
# 005720 already done
# 005725 skipped because it does not end with 0
# 005745 skipped because it does not end with 0
# 005750 already done
# 005771 skipped because it does not end with 0
# 005791 skipped because it does not end with 0
# 005795 skipped because it does not end with 0
# 005797 skipped because it does not end with 0
# 005800 already done
# 005810 already done
# 005820 already done
# 005830 already done
# 005850 already done
# 005871 skipped because it does not end with 0
# 005880 already done
# 005895 skipped because it does not end with 0
# 005897 skipped because it does not end with 0
# 005931 skipped because it does not end with 0
# 005932 skipped because it does not end with 0
# 005933 skipped because it does not end with 0
# 005935 skipped because it does not end with 0
# 005936 skipped because it does not end with 0
# 005937 skipped because it does not end with 0
# 005940 already done
# 005945 skipped because it does not end with 0
# 005950 already done
# 005960 already done
# 005961 skipped because it does not end with 0
# 005965 skipped because it does not end with 0
# 005981 skipped because it does not end with 0
# 006040 already done
# 006060 already done
# 006090 already done
# 006110 already done
# 006120 already done
# 006125 skipped because it does not end with 0
# 006140 already done
# 006151 skipped because it does not end with 0
# 006161 skipped because it does not end with 0
# 006165 skipped because it does not end with 0
# 006200 already done
# 006220 already done
# 006241 skipped because it does not end with 0
# 006242 skipped because it does not end with 0
# 006260 already done
# 006281 skipped because it does not end with 0
# 006295 skipped because it does not end with 0
# 006301 skipped because it does not end with 0
# 006345 skipped because it does not end with 0
# 006347 skipped because it does not end with 0
# 006351 skipped because it does not end with 0
# 006360 already done
# 006370 already done
# 006371 skipped because it does not end with 0
# 006375 skipped because it does not end with 0
# 006376 skipped because it does not end with 0
# 006380 already done
# 006390 already done
# 006400 already done
# 006401 skipped because it does not end with 0
# 006405 skipped because it does not end with 0
# 006406 skipped because it does not end with 0
# 006441 skipped because it does not end with 0
# 006445 skipped because it does not end with 0
# 006515 skipped because it does not end with 0
# 006570 already done
# 006571 skipped because it does not end with 0
# 006580 already done
# 006601 skipped because it does not end with 0
# 006605 skipped because it does not end with 0
# 006611 skipped because it does not end with 0
# 006650 already done
# 006740 already done
# 006800 already done
# 006805 skipped because it does not end with 0
# 00680K skipped because it does not end with 0
# 006840 already done
# 006890 already done
# 006891 skipped because it does not end with 0
# 006892 skipped because it does not end with 0
# 006893 skipped because it does not end with 0
# 006921 skipped because it does not end with 0
# 006980 already done
# 007021 skipped because it does not end with 0
# 007022 skipped because it does not end with 0
# 007070 already done
# 007091 skipped because it does not end with 0
# 007111 skipped because it does not end with 0
# 007120 already done
# 007121 skipped because it does not end with 0
# 007160 already done
# 007161 skipped because it does not end with 0
# 007171 skipped because it does not end with 0
# 007191 skipped because it does not end with 0
# 007195 skipped because it does not end with 0
# 007197 skipped because it does not end with 0
# 007210 already done
# 007241 skipped because it does not end with 0
# 007280 already done
# 007310 already done
# 007330 already done
# 007340 already done
# 007361 skipped because it does not end with 0
# 007362 skipped because it does not end with 0
# 007365 skipped because it does not end with 0
# 007367 skipped because it does not end with 0
# 007369 skipped because it does not end with 0
# 00736A skipped because it does not end with 0
# 00736B skipped because it does not end with 0
# 00736C skipped because it does not end with 0
# 00736D skipped because it does not end with 0
# 00736E skipped because it does not end with 0
# 007370 already done
# 007381 skipped because it does not end with 0
# 007411 skipped because it does not end with 0
# 007461 skipped because it does not end with 0
# 007531 skipped because it does not end with 0
# 007540 already done
# 007541 skipped because it does not end with 0
# 007571 skipped because it does not end with 0
# 007575 skipped because it does not end with 0
# 007590 already done
# 007595 skipped because it does not end with 0
# 007611 skipped because it does not end with 0
# 007631 skipped because it does not end with 0
# 007641 skipped because it does not end with 0
# 007660 already done
# 007680 already done
# 007690 already done
# 007691 skipped because it does not end with 0
# 007700 already done
# 007720 already done
# 007721 skipped because it does not end with 0
# 007770 already done
# 007801 skipped because it does not end with 0
# 007802 skipped because it does not end with 0
# 007810 already done
# 007815 skipped because it does not end with 0
# 00781K skipped because it does not end with 0
# 007860 already done
# 007980 already done
# 007981 skipped because it does not end with 0
# 008001 skipped because it does not end with 0
# 008002 skipped because it does not end with 0
# 008040 already done
# 008051 skipped because it does not end with 0
# 008060 already done
# 00806K skipped because it does not end with 0
# 008105 skipped because it does not end with 0
# 008110 already done
# 008121 skipped because it does not end with 0
# 008124 skipped because it does not end with 0
# 008191 skipped because it does not end with 0
# 008250 already done
# 008260 already done
# 008264 skipped because it does not end with 0
# 008321 skipped because it does not end with 0
# 008351 skipped because it does not end with 0
# 008355 skipped because it does not end with 0
# 008370 already done
# 008371 skipped because it does not end with 0
# 008405 skipped because it does not end with 0
# 008420 already done
# 008421 skipped because it does not end with 0
# 008470 already done
# 008485 skipped because it does not end with 0
# 008490 already done
# 008500 already done
# 008541 skipped because it does not end with 0
# 008581 skipped because it does not end with 0
# 008600 already done
# 008675 skipped because it does not end with 0
# 008691 skipped because it does not end with 0
# 008705 skipped because it does not end with 0
# 008721 skipped because it does not end with 0
# 008730 already done
# 008775 skipped because it does not end with 0
# 008811 skipped because it does not end with 0
# 008870 already done
# 008891 skipped because it does not end with 0
# 008895 skipped because it does not end with 0
# 008921 skipped because it does not end with 0
# 008931 skipped because it does not end with 0
# 008971 skipped because it does not end with 0
# 008975 skipped because it does not end with 0
# 008985 skipped because it does not end with 0
# 009011 skipped because it does not end with 0
# 009035 skipped because it does not end with 0
# 009037 skipped because it does not end with 0
# 009085 skipped because it does not end with 0
# 009140 already done
# 009141 skipped because it does not end with 0
# 009151 skipped because it does not end with 0
# 009155 skipped because it does not end with 0
# 009156 skipped because it does not end with 0
# 009160 already done
# 009180 already done
# 009190 already done
# 009200 already done
# 009201 skipped because it does not end with 0
# 009240 already done
# 009270 already done
# 009271 skipped because it does not end with 0
# 009275 skipped because it does not end with 0
# 009281 skipped because it does not end with 0
# 009290 already done
# 009300 already done
# 009310 already done
# 009311 skipped because it does not end with 0
# 009331 skipped because it does not end with 0
# 009335 skipped because it does not end with 0
# 009337 skipped because it does not end with 0
# 009381 skipped because it does not end with 0
# 009385 skipped because it does not end with 0
# 009410 already done
# 009415 skipped because it does not end with 0
# 009420 already done
# 009440 already done
# 009441 skipped because it does not end with 0
# 009450 already done
# 009451 skipped because it does not end with 0
# 009460 already done
# 009470 already done
# 009520 already done
# 009580 already done
# 009651 skipped because it does not end with 0
# 009655 skipped because it does not end with 0
# 009680 already done
# 009681 skipped because it does not end with 0
# 009691 skipped because it does not end with 0
# 009692 skipped because it does not end with 0
# 009721 skipped because it does not end with 0
# 009731 skipped because it does not end with 0
# 009770 already done
# 009780 already done
# 009781 skipped because it does not end with 0
# 009795 skipped because it does not end with 0
# 009811 skipped because it does not end with 0
# 009815 skipped because it does not end with 0
# 009816 skipped because it does not end with 0
# 009830 already done
# 009831 skipped because it does not end with 0
# 009835 skipped because it does not end with 0
# 009837 skipped because it does not end with 0
# 009891 skipped because it does not end with 0
# 009895 skipped because it does not end with 0
# 009897 skipped because it does not end with 0
# 009970 already done
# 009995 skipped because it does not end with 0
# 010040 already done
# 010041 skipped because it does not end with 0
# 010051 skipped because it does not end with 0
# 010060 already done
# 010095 skipped because it does not end with 0
# 010100 already done
# 010120 already done
# 010130 already done
# 010140 already done
# 010141 skipped because it does not end with 0
# 010142 skipped because it does not end with 0
# 010145 skipped because it does not end with 0
# 010221 skipped because it does not end with 0
# 010240 already done
# 010400 already done
# 010420 already done
# 010421 skipped because it does not end with 0
# 010422 skipped because it does not end with 0
# 010470 already done
# 010521 skipped because it does not end with 0
# 010581 skipped because it does not end with 0
# 010600 already done
# 010601 skipped because it does not end with 0
# 010602 skipped because it does not end with 0
# 010620 already done
# 010640 already done
# 010641 skipped because it does not end with 0
# 010660 already done
# 010671 skipped because it does not end with 0
# 010672 skipped because it does not end with 0
# 010690 already done
# 010691 skipped because it does not end with 0
# 010692 skipped because it does not end with 0
# 010731 skipped because it does not end with 0
# 010770 already done
# 010780 already done
# 010781 skipped because it does not end with 0
# 010950 already done
# 010955 skipped because it does not end with 0
# 010960 already done
# 011000 already done
# 011021 skipped because it does not end with 0
# 011022 skipped because it does not end with 0
# 011040 already done
# 011051 skipped because it does not end with 0
# 011080 already done
# 011090 already done
# 011091 skipped because it does not end with 0
# 011155 skipped because it does not end with 0
# 011170 already done
# 011200 already done
# 011201 skipped because it does not end with 0
# 011280 already done
# 011281 skipped because it does not end with 0
# 011301 skipped because it does not end with 0
# 011302 skipped because it does not end with 0
# 011303 skipped because it does not end with 0
# 011321 skipped because it does not end with 0
# 011330 already done
# 011370 already done
# 011390 already done
# 011420 already done
# 011471 skipped because it does not end with 0
# 011500 already done
# 011511 skipped because it does not end with 0
# 011560 already done
# 011651 skipped because it does not end with 0
# 011652 skipped because it does not end with 0
# 011691 skipped because it does not end with 0
# 011692 skipped because it does not end with 0
# 011700 already done
# 011721 skipped because it does not end with 0
# 011724 skipped because it does not end with 0
# 011760 already done
# 011761 skipped because it does not end with 0
# 011780 already done
# 011785 skipped because it does not end with 0
# 011790 already done
# 011791 skipped because it does not end with 0
# 011810 already done
# 011815 skipped because it does not end with 0
# 011821 skipped because it does not end with 0
# 011825 skipped because it does not end with 0
# 011841 skipped because it does not end with 0
# 011931 skipped because it does not end with 0
# 011941 skipped because it does not end with 0
# 012030 already done
# 012091 skipped because it does not end with 0
# 012095 skipped because it does not end with 0
# 012160 already done
# 012195 skipped because it does not end with 0
# 012200 already done
# 012201 skipped because it does not end with 0
# 012205 skipped because it does not end with 0
# 012224 skipped because it does not end with 0
# 012251 skipped because it does not end with 0
# 012261 skipped because it does not end with 0
# 012265 skipped because it does not end with 0
# 012280 already done
# 012320 already done
# 012335 skipped because it does not end with 0
# 012337 skipped because it does not end with 0
# 012401 skipped because it does not end with 0
# 012405 skipped because it does not end with 0
# 012451 skipped because it does not end with 0
# 012461 skipped because it does not end with 0
# 012581 skipped because it does not end with 0
# 012600 already done
# 012601 skipped because it does not end with 0
# 012605 skipped because it does not end with 0
# 012610 already done
# 012611 skipped because it does not end with 0
# 012612 skipped because it does not end with 0
# 012630 already done
# 012631 skipped because it does not end with 0
# 012655 skipped because it does not end with 0
# 012690 already done
# 012691 skipped because it does not end with 0
# 012700 already done
# 012721 skipped because it does not end with 0
# 012751 skipped because it does not end with 0
# 012761 skipped because it does not end with 0
# 012800 already done
# 012805 skipped because it does not end with 0
# 012860 already done
# 012861 skipped because it does not end with 0
# 013001 skipped because it does not end with 0
# 013005 skipped because it does not end with 0
# 013030 already done
# 013031 skipped because it does not end with 0
# 013034 skipped because it does not end with 0
# 013035 skipped because it does not end with 0
# 013041 skipped because it does not end with 0
# 013091 skipped because it does not end with 0
# 013095 skipped because it does not end with 0
# 013097 skipped because it does not end with 0
# 013120 already done
# 013201 skipped because it does not end with 0
# 013241 skipped because it does not end with 0
# 013251 skipped because it does not end with 0
# 013255 skipped because it does not end with 0
# 013360 already done
# 013361 skipped because it does not end with 0
# 013365 skipped because it does not end with 0
# 013367 skipped because it does not end with 0
# 013520 already done
# 013570 already done
# 013575 skipped because it does not end with 0
# 013580 already done
# 013635 skipped because it does not end with 0
# 013651 skipped because it does not end with 0
# 013691 skipped because it does not end with 0
# 013700 already done
# 013721 skipped because it does not end with 0
# 013781 skipped because it does not end with 0
# 013782 skipped because it does not end with 0
# 013870 already done
# 013890 already done
# 013990 already done
# 014015 skipped because it does not end with 0
# 014041 skipped because it does not end with 0
# 014045 skipped because it does not end with 0
# 014047 skipped because it does not end with 0
# 014081 skipped because it does not end with 0
# 014082 skipped because it does not end with 0
# 014161 skipped because it does not end with 0
# 014190 already done
# 014200 already done
# 014280 already done
# 014285 skipped because it does not end with 0
# 014351 skipped because it does not end with 0
# 014391 skipped because it does not end with 0
# 014440 already done
# 014491 skipped because it does not end with 0
# 014530 already done
# 014570 already done
# 014580 already done
# 014581 skipped because it does not end with 0
# 014665 skipped because it does not end with 0
# 014680 already done
# 014681 skipped because it does not end with 0
# 014682 skipped because it does not end with 0
# 014745 skipped because it does not end with 0
# 014790 already done
# 014820 already done
# 014821 skipped because it does not end with 0
# 014825 skipped because it does not end with 0
# 014827 skipped because it does not end with 0
# 014830 already done
# 014915 skipped because it does not end with 0
# 014970 already done
# 014981 skipped because it does not end with 0
# 014991 skipped because it does not end with 0
# 015020 already done
# 015021 skipped because it does not end with 0
# 015054 skipped because it does not end with 0
# 015081 skipped because it does not end with 0
# 015111 skipped because it does not end with 0
# 015230 already done
# 015265 skipped because it does not end with 0
# 015360 already done
# 015531 skipped because it does not end with 0
# 015532 skipped because it does not end with 0
# 015535 skipped because it does not end with 0
# 015541 skipped because it does not end with 0
# 015545 skipped because it does not end with 0
# 015581 skipped because it does not end with 0
# 015585 skipped because it does not end with 0
# 015590 already done
# 015675 skipped because it does not end with 0
# 015710 already done
# 015750 already done
# 015760 already done
# 015761 skipped because it does not end with 0
# 015860 already done
# 015881 skipped because it does not end with 0
# 015890 already done
# 015891 skipped because it does not end with 0
# 015941 skipped because it does not end with 0
# 015981 skipped because it does not end with 0
# 015982 skipped because it does not end with 0
# 016090 already done
# 016091 skipped because it does not end with 0
# 016092 skipped because it does not end with 0
# 016161 skipped because it does not end with 0
# 016167 skipped because it does not end with 0
# 016250 already done
# 016355 skipped because it does not end with 0
# 016360 already done
# 016361 skipped because it does not end with 0
# 016365 skipped because it does not end with 0
# 016367 skipped because it does not end with 0
# 016380 already done
# 016385 skipped because it does not end with 0
# 016391 skipped because it does not end with 0
# 016395 skipped because it does not end with 0
# 016397 skipped because it does not end with 0
# 016435 skipped because it does not end with 0
# 016450 already done
# 016451 skipped because it does not end with 0
# 016501 skipped because it does not end with 0
# 016511 skipped because it does not end with 0
# 016551 skipped because it does not end with 0
# 016555 skipped because it does not end with 0
# 016575 skipped because it does not end with 0
# 016580 already done
# 016581 skipped because it does not end with 0
# 016590 already done
# 016591 skipped because it does not end with 0
# 016592 skipped because it does not end with 0
# 016593 skipped because it does not end with 0
# 016600 already done
# 016601 skipped because it does not end with 0
# 016610 already done
# 016611 skipped because it does not end with 0
# 016641 skipped because it does not end with 0
# 016681 skipped because it does not end with 0
# 016682 skipped because it does not end with 0
# 016691 skipped because it does not end with 0
# 016692 skipped because it does not end with 0
# 016710 already done
# 016740 already done
# 016800 already done
# 016831 skipped because it does not end with 0
# 016835 skipped because it does not end with 0
# 016836 skipped because it does not end with 0
# 016837 skipped because it does not end with 0
# 016838 skipped because it does not end with 0
# 016839 skipped because it does not end with 0
# 01683C skipped because it does not end with 0
# 016880 already done
# 016881 skipped because it does not end with 0
# 016920 already done
# 016921 skipped because it does not end with 0
# 016925 skipped because it does not end with 0
# 016975 skipped because it does not end with 0
# 017041 skipped because it does not end with 0
# 017042 skipped because it does not end with 0
# 017043 skipped because it does not end with 0
# 017091 skipped because it does not end with 0
# 017092 skipped because it does not end with 0
# 017093 skipped because it does not end with 0
# 017094 skipped because it does not end with 0
# 017121 skipped because it does not end with 0
# 017161 skipped because it does not end with 0
# 017171 skipped because it does not end with 0
# 017211 skipped because it does not end with 0
# 017214 skipped because it does not end with 0
# 017250 already done
# 017301 skipped because it does not end with 0
# 017302 skipped because it does not end with 0
# 017321 skipped because it does not end with 0
# 017322 skipped because it does not end with 0
# 017325 skipped because it does not end with 0
# 017370 already done
# 017390 already done
# 017391 skipped because it does not end with 0
# 017480 already done
# 017510 already done
# 017550 already done
# 017551 skipped because it does not end with 0
# 017555 skipped because it does not end with 0
# 017670 already done
# 017671 skipped because it does not end with 0
# 017674 skipped because it does not end with 0
# 017800 already done
# 017801 skipped because it does not end with 0
# 017811 skipped because it does not end with 0
# 017891 skipped because it does not end with 0
# 017900 already done
# 017901 skipped because it does not end with 0
# 017940 already done
# 017941 skipped because it does not end with 0
# 017960 already done
# 017961 skipped because it does not end with 0
# 017962 skipped because it does not end with 0
# 018121 skipped because it does not end with 0
# 018361 skipped because it does not end with 0
# 018365 skipped because it does not end with 0
# 018366 skipped because it does not end with 0
# 018411 skipped because it does not end with 0
# 018415 skipped because it does not end with 0
# 018417 skipped because it does not end with 0
# 018470 already done
# 018471 skipped because it does not end with 0
# 018485 skipped because it does not end with 0
# 018500 already done
# 018501 skipped because it does not end with 0
# 018571 skipped because it does not end with 0
# 018620 already done
# 018670 already done
# 018880 already done
# 018881 skipped because it does not end with 0
# 019010 already done
# 019011 skipped because it does not end with 0
# 019170 already done
# 019175 skipped because it does not end with 0
# 019180 already done
# 019181 skipped because it does not end with 0
# 019210 already done
# 019301 skipped because it does not end with 0
# 019440 already done
# 019490 already done
# 019491 skipped because it does not end with 0
# 019492 skipped because it does not end with 0
# 019540 already done
# 019550 already done
# 019641 skipped because it does not end with 0
# 019680 already done
# 019685 skipped because it does not end with 0
# 019931 skipped because it does not end with 0
# 020000 already done
# 020001 skipped because it does not end with 0
# 020074 skipped because it does not end with 0
# 020075 skipped because it does not end with 0
# 020121 skipped because it does not end with 0
# 020560 already done
# 020625 skipped because it does not end with 0
# 020760 already done
# 020865 skipped because it does not end with 0
# 020881 skipped because it does not end with 0
# 021045 skipped because it does not end with 0
# 021050 already done
# 021080 already done
# 021171 skipped because it does not end with 0
# 021221 skipped because it does not end with 0
# 021240 already done
# 021320 already done
# 021650 already done
# 021820 already done
# 021880 already done
# 021931 skipped because it does not end with 0
# 022061 skipped because it does not end with 0
# 022875 skipped because it does not end with 0
# 023000 already done
# 023131 skipped because it does not end with 0
# 023135 skipped because it does not end with 0
# 023136 skipped because it does not end with 0
# 023137 skipped because it does not end with 0
# 023138 skipped because it does not end with 0
# 023139 skipped because it does not end with 0
# 023150 already done
# 023410 already done
# 023421 skipped because it does not end with 0
# 023440 already done
# 023441 skipped because it does not end with 0
# 023442 skipped because it does not end with 0
# 023450 already done
# 023460 already done
# 023590 already done
# 023591 skipped because it does not end with 0
# 023601 skipped because it does not end with 0
# 023760 already done
# 023771 skipped because it does not end with 0
# 023800 already done
# 023810 already done
# 023811 skipped because it does not end with 0
# 023900 already done
# 023960 already done
# 024070 already done
# 024071 skipped because it does not end with 0
# 024081 skipped because it does not end with 0
# 024090 already done
# 024091 skipped because it does not end with 0
# 024092 skipped because it does not end with 0
# 024093 skipped because it does not end with 0
# 024101 skipped because it does not end with 0
# 024110 already done
# 024120 already done
# 024720 already done
# 024740 already done
# 024741 skipped because it does not end with 0
# 024811 skipped because it does not end with 0
# 024871 skipped because it does not end with 0
# 024880 already done
# 024890 already done
# 024900 already done
# 024911 skipped because it does not end with 0
# 024912 skipped because it does not end with 0
# 024951 skipped because it does not end with 0
# 025000 already done
# 025151 skipped because it does not end with 0
# 025451 skipped because it does not end with 0
# 025530 already done
# 025541 skipped because it does not end with 0
# 025542 skipped because it does not end with 0
# 025551 skipped because it does not end with 0
# 025561 skipped because it does not end with 0
# 025562 skipped because it does not end with 0
# 025621 skipped because it does not end with 0
# 025750 already done
# 025820 already done
# 025821 skipped because it does not end with 0
# 025831 skipped because it does not end with 0
# 025841 skipped because it does not end with 0
# 025851 skipped because it does not end with 0
# 025860 already done
# 025880 already done
# 025890 already done
# 025891 skipped because it does not end with 0
# 025901 skipped because it does not end with 0
# 025921 skipped because it does not end with 0
# 025931 skipped because it does not end with 0
# 025950 already done
# 025951 skipped because it does not end with 0
# 025981 skipped because it does not end with 0
# 026040 already done
# 026151 skipped because it does not end with 0
# 026231 skipped because it does not end with 0
# 026251 skipped because it does not end with 0
# 026261 skipped because it does not end with 0
# 026262 skipped because it does not end with 0
# 026263 skipped because it does not end with 0
# 026871 skipped because it does not end with 0
# 026872 skipped because it does not end with 0
# 026890 already done
# 026910 already done
# 026921 skipped because it does not end with 0
# 026940 already done
# 026941 skipped because it does not end with 0
# 026961 skipped because it does not end with 0
# 026962 skipped because it does not end with 0
# 027351 skipped because it does not end with 0
# 027352 skipped because it does not end with 0
# 027353 skipped because it does not end with 0
# 027354 skipped because it does not end with 0
# 027360 already done
# 027410 already done
# 027461 skipped because it does not end with 0
# 027465 skipped because it does not end with 0
# 027467 skipped because it does not end with 0
# 027469 skipped because it does not end with 0
# 027611 skipped because it does not end with 0
# 027612 skipped because it does not end with 0
# 027613 skipped because it does not end with 0
# 027614 skipped because it does not end with 0
# 027710 already done
# 027711 skipped because it does not end with 0
# 027712 skipped because it does not end with 0
# 027740 already done
# 027830 already done
# 027841 skipped because it does not end with 0
# 027891 skipped because it does not end with 0
# 027892 skipped because it does not end with 0
# 027893 skipped because it does not end with 0
# 027894 skipped because it does not end with 0
# 027970 already done
# 028050 already done
# 028081 skipped because it does not end with 0
# 028091 skipped because it does not end with 0
# 028092 skipped because it does not end with 0
# 02826K skipped because it does not end with 0
# 028301 skipped because it does not end with 0
# 028302 skipped because it does not end with 0
# 028303 skipped because it does not end with 0
# 028304 skipped because it does not end with 0
# 028305 skipped because it does not end with 0
# 028670 already done
# 029461 skipped because it does not end with 0
# 029462 skipped because it does not end with 0
# 029463 skipped because it does not end with 0
# 029464 skipped because it does not end with 0
# 029471 skipped because it does not end with 0
# 029472 skipped because it does not end with 0
# 029481 skipped because it does not end with 0
# 029530 already done
# 029780 already done
# 030190 already done
# 030200 already done
# 030210 already done
# 030211 skipped because it does not end with 0
# 030421 skipped because it does not end with 0
# 030520 already done
# 030521 skipped because it does not end with 0
# 030522 skipped because it does not end with 0
# 030524 skipped because it does not end with 0
# 030531 skipped because it does not end with 0
# 030532 skipped because it does not end with 0
# 030610 already done
# 030711 skipped because it does not end with 0
# 030720 already done
# 030721 skipped because it does not end with 0
# 030960 already done
# 031310 already done
# 031314 skipped because it does not end with 0
# 031330 already done
# 031510 already done
# 031804 skipped because it does not end with 0
# 031951 skipped because it does not end with 0
# 031955 skipped because it does not end with 0
# 031958 skipped because it does not end with 0
# 031971 skipped because it does not end with 0
# 031972 skipped because it does not end with 0
# 031974 skipped because it does not end with 0
# 031980 already done
# 032080 already done
# 032151 skipped because it does not end with 0
# 032190 already done
# 032280 already done
# 032421 skipped because it does not end with 0
# 032500 already done
# 032540 already done
# 032581 skipped because it does not end with 0
# 032582 skipped because it does not end with 0
# 032591 skipped because it does not end with 0
# 032611 skipped because it does not end with 0
# 032612 skipped because it does not end with 0
# 032621 skipped because it does not end with 0
# 032624 skipped because it does not end with 0
# 032640 already done
# 032685 skipped because it does not end with 0
# 032750 already done
# 032791 skipped because it does not end with 0
# 032801 skipped because it does not end with 0
# 032802 skipped because it does not end with 0
# 032830 already done
# 032941 skipped because it does not end with 0
# 033041 skipped because it does not end with 0
# 033050 already done
# 033075 skipped because it does not end with 0
# 033100 already done
# 033130 already done
# 033160 already done
# 033180 already done
# 033200 already done
# 033240 already done
# 033250 already done
# 033290 already done
# 033320 already done
# 033334 skipped because it does not end with 0
# 033340 already done
# 033500 already done
# 033530 already done
# 033540 already done
# 033725 skipped because it does not end with 0
# 033780 already done
# 033790 already done
# 033830 already done
# 033855 skipped because it does not end with 0
# 033885 skipped because it does not end with 0
# 033920 already done
# 034120 already done
# 034121 skipped because it does not end with 0
# 034220 already done
# 034230 already done
# 034300 already done
# 034310 already done
# 034590 already done
# 034607 skipped because it does not end with 0
# 034730 already done
# 03473K skipped because it does not end with 0
# 03481K skipped because it does not end with 0
# 034830 already done
# 035000 already done
# 035150 already done
# 035250 already done
# 035405 skipped because it does not end with 0
# 035510 already done
# 035600 already done
# 035810 already done
# 035890 already done
# 035915 skipped because it does not end with 0
# 035917 skipped because it does not end with 0
# 035919 skipped because it does not end with 0
# 036000 already done
# 036010 already done
# 036190 already done
# 036200 already done
# 036220 already done
# 036460 already done
# 036530 already done
# 036560 already done
# 036580 already done
# 036585 skipped because it does not end with 0
# 036640 already done
# 036670 already done
# 036690 already done
# 036710 already done
# 036800 already done
# 036825 skipped because it does not end with 0
# 036890 already done
# 037070 already done
# 037230 already done
# 037270 already done
# 037330 already done
# 037350 already done
# 037460 already done
# 037710 already done
# 037760 already done
# 038010 already done
# 038070 already done
# 038110 already done
# 038390 already done
# 038540 already done
# 038950 already done
# 039010 already done
# 039020 already done
# 039240 already done
# 039310 already done
# 039340 already done
# 039440 already done
# 039490 already done
# 039560 already done
# 039570 already done
# 039830 already done
# 039980 already done
# 040910 already done
# 041190 already done
# ...
# 079950 already done
# 079960 already done
# 079980 already done
# 080010 already done
# 080160 already done
# 080420 already done
# 080470 already done
# 080520 already done
# 081580 already done
# 082270 already done
# 082640 already done
# 082660 already done
# 083420 already done
# 083450 already done
# 083550 already done
# 083640 already done
# 083660 already done
# 083930 already done
# 084010 already done
# 084180 already done
# 084670 already done
# 084690 already done
# 084695 skipped because it does not end with 0
# 084697 skipped because it does not end with 0
# 084730 already done
# 084870 already done
# 08537M skipped because it does not end with 0
# 085620 already done
# 085660 already done
# 085670 already done
# 085810 already done
# 085910 already done
# 086060 already done
# 086280 already done
# 086670 already done
# 086790 already done
# 086960 already done
# 088130 already done
# 088350 already done
# 088790 already done
# 088800 already done
# 089010 already done
# 089140 already done
# 089150 already done
# 089470 already done
# 089590 already done
# 089600 already done
# 089790 already done
# 089860 already done
# 090080 already done
# 090350 already done
# 090355 skipped because it does not end with 0
# 090410 already done
# 090435 skipped because it does not end with 0
# 090470 already done
# 091120 already done
# 091340 already done
# 091580 already done
# 091590 already done
# 091700 already done
# 092070 already done
# 092200 already done
# 092220 already done
# 092230 already done
# 092300 already done
# 092440 already done
# 092460 already done
# 092600 already done
# 092730 already done
# 092780 already done
# 092790 already done
# 093050 already done
# 093190 already done
# 093230 already done
# 093240 already done
# 093380 already done
# 093520 already done
# 093640 already done
# 093920 already done
# 094820 already done
# 094850 already done
# 094940 already done
# 094970 already done
# 095190 already done
# 095340 already done
# 095500 already done
# 095570 already done
# 095610 already done
# 095720 already done
# 096530 already done
# 096690 already done
# 096770 already done
# 096775 skipped because it does not end with 0
# 097780 already done
# 097870 already done
# 097955 skipped because it does not end with 0
# 097957 skipped because it does not end with 0
# 097959 skipped because it does not end with 0
# 098120 already done
# 098660 already done
# 099220 already done
# 099410 already done
# 099440 already done
# 100030 데이터베이스에 저장 완료
# 100090 no.3 pass condition
# 100120 no.3 pass condition
# 100130 no.3 pass condition
# 100220 데이터베이스에 저장 완료
# 100250 데이터베이스에 저장 완료
# 100590 no.3 pass condition
# 100660 no.3 pass condition
# 100700 no.3 pass condition
# 100790 데이터베이스에 저장 완료
# 100840 데이터베이스에 저장 완료
# 101000 no.3 pass condition
# 101060 no.3 pass condition
# 101140 no.3 pass condition
# 101160 no.3 pass condition
# 101170 데이터베이스에 저장 완료
# 101240 데이터베이스에 저장 완료
# 101330 데이터베이스에 저장 완료
# 101360 no.3 pass condition
# 101380 no.2 pass condition
# 101390 no.3 pass condition
# 101400 no.3 pass condition
# 101490 no.3 pass condition
# 101530 데이터베이스에 저장 완료
# 101670 데이터베이스에 저장 완료
# 101680 no.3 pass condition
# 101730 no.3 pass condition
# 101790 no.2 pass condition
# 101930 데이터베이스에 저장 완료
# 101970 no.3 pass condition
# 101990 no.3 pass condition
# 102000 no.2 pass condition
# 102120 no.3 pass condition
# 1163 days 16:00:21.386055 2024-06-22 16:00:21.386055 2021-04-16 00:00:00
# 102210 데이터베이스에 저장 완료
# 102260 데이터베이스에 저장 완료
# 102280 no.3 pass condition
# 102370 no.3 pass condition
# 102460 no.3 pass condition
# 102710 no.3 pass condition
# 102940 no.3 pass condition
# 103130 no.3 pass condition
# 103140 데이터베이스에 저장 완료
# 103150 no.3 pass condition
# 103155 skipped because it does not end with 0
# 103160 no.3 pass condition
# 103230 데이터베이스에 저장 완료
# 103590 no.3 pass condition
# 103840 no.3 pass condition
# 104040 데이터베이스에 저장 완료
# 2732 days 16:00:21.386055 2024-06-22 16:00:21.386055 2016-12-29 00:00:00
# 104110 데이터베이스에 저장 완료
# 2732 days 16:00:21.386055 2024-06-22 16:00:21.386055 2016-12-29 00:00:00
# 104120 데이터베이스에 저장 완료
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File e:\아경\AI\Python38\lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File e:\아경\AI\Python38\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File e:\아경\AI\Python38\lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# File e:\아경\AI\Python38\lib\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#
# File e:\아경\AI\Python38\lib\site-packages\urllib3\connectionpool.py:496, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     495 try:
# --> 496     conn.request(
#     497         method,
#     498         url,
#     499         body=body,
#     500         headers=headers,
#     501         chunked=chunked,
#     502         preload_content=preload_content,
#     503         decode_content=decode_content,
#     504         enforce_content_length=enforce_content_length,
#     505     )
#     507 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     508 # legitimately able to close the connection after sending a valid response.
#     509 # With this behaviour, the received response is still readable.
#
# File e:\아경\AI\Python38\lib\site-packages\urllib3\connection.py:400, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     399     self.putheader(header, value)
# --> 400 self.endheaders()
#     402 # If we're given a body we start sending that in chunks.
#
# File e:\아경\AI\Python38\lib\http\client.py:1250, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1249     raise CannotSendHeader()
# -> 1250 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File e:\아경\AI\Python38\lib\http\client.py:1010, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1009 del self._buffer[:]
# -> 1010 self.send(msg)
#    1012 if message_body is not None:
#    1013
#    1014     # create a consistent interface to message_body
#
# File e:\아경\AI\Python38\lib\http\client.py:950, in HTTPConnection.send(self, data)
#     949 if self.auto_open:
# --> 950     self.connect()
#     951 else:
#
# File e:\아경\AI\Python38\lib\site-packages\urllib3\connection.py:238, in HTTPConnection.connect(self)
#     237 def connect(self) -> None:
# --> 238     self.sock = self._new_conn()
#     239     if self._tunnel_host:
#     240         # If we're tunneling it means we're connected to our proxy.
#
# File e:\아경\AI\Python38\lib\site-packages\urllib3\connection.py:213, in HTTPConnection._new_conn(self)
#     212 except OSError as e:
# --> 213     raise NewConnectionError(
#     214         self, f"Failed to establish a new connection: {e}"
#     215     ) from e
#     217 # Audit hooks are only available in Python 3.8+
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x0000021DEFA97220>: Failed to establish a new connection: [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File e:\아경\AI\Python38\lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File e:\아경\AI\Python38\lib\site-packages\urllib3\connectionpool.py:847, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     845     new_e = ProtocolError("Connection aborted.", new_e)
# --> 847 retries = retries.increment(
#     848     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     849 )
#     850 retries.sleep()
#
# File e:\아경\AI\Python38\lib\site-packages\urllib3\util\retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='data.krx.co.kr', port=80): Max retries exceeded with url: /comm/bldAttendant/getJsonData.cmd (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000021DEFA97220>: Failed to establish a new connection: [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[15], line 62
#      60 end_date = current_date.strftime("%Y%m%d")
#      61 time.sleep(3)
# ---> 62 df2 = stock.get_market_fundamental(start_date, end_date, ticker)
#      65 if df2.empty or 'PER' not in df2.columns:
#      66     cur.execute(f"UPDATE ticker_status SET status = 'completed' WHERE ticker = '{ticker}'")
#
# File e:\아경\AI\Python38\lib\site-packages\pykrx\stock\stock_api.py:678, in get_market_fundamental(*args, **kwargs)
#     675 dates = list(filter(regex_yymmdd.match, [str(x) for x in args]))
#     676 if len(dates) == 2 or ('fromdate' in kwargs and
#     677                        'todate' in kwargs):
# --> 678     return get_market_fundamental_by_date(*args, **kwargs)
#     679 else:
#     680     return get_market_fundamental_by_ticker(*args, **kwargs)
#
# File e:\아경\AI\Python38\lib\site-packages\pykrx\stock\stock_api.py:728, in get_market_fundamental_by_date(fromdate, todate, ticker, freq, name_display)
#     725 fromdate = fromdate.replace("-", "")
#     726 todate = todate.replace("-", "")
# --> 728 df = krx.get_market_fundamental_by_date(fromdate, todate, ticker)
#     730 if df.empty:
#     731     return df
#
# File e:\아경\AI\Python38\lib\site-packages\pykrx\website\comm\util.py:8, in dataframe_empty_handler.<locals>.wrapper(*args, **kwargs)
#       6 def wrapper(*args, **kwargs):
#       7     try:
# ----> 8         return func(*args, **kwargs)
#       9     except (AttributeError, KeyError, TypeError, ValueError) as e:
#      10         logging.info(args, kwargs)
#
# File e:\아경\AI\Python38\lib\site-packages\pykrx\website\krx\market\wrap.py:263, in get_market_fundamental_by_date(fromdate, todate, ticker)
#     260 isin = get_stock_ticker_isin(ticker)
#     261 # market = get_stock_ticekr_market(ticker)
# --> 263 df = PER_PBR_배당수익률_개별().fetch(fromdate, todate, "ALL", isin)
#     265 df = df[['TRD_DD', 'BPS', 'PER', 'PBR', 'EPS', 'DVD_YLD', 'DPS']]
#     266 df.columns = ['날짜', 'BPS', 'PER', 'PBR', 'EPS', 'DIV', 'DPS']
#
# File e:\아경\AI\Python38\lib\site-packages\pykrx\website\krx\market\core.py:228, in PER_PBR_배당수익률_개별.fetch(self, strtDd, endDd, mktId, isuCd)
#     202 def fetch(self, strtDd: str, endDd: str, mktId: str, isuCd: str) \
#     203         -> DataFrame:
#     204     """[12021] PER/PBR/배당수익률
#     205
#     206     Args:
#    (...)
#     226             5,997  7.59  28,126  1.62  850    1.87
#     227     """
# --> 228     result = self.read(mktId=mktId, strtDd=strtDd, endDd=endDd,
#     229                        isuCd=isuCd)
#     230     return DataFrame(result['output'])
#
# File e:\아경\AI\Python38\lib\site-packages\pykrx\website\krx\krxio.py:36, in KrxWebIo.read(self, **params)
#      34 params['endDd'] = dt_tmp.strftime("%Y%m%d")
#      35 dt_s += delta + pd.to_timedelta('1 days')
# ---> 36 resp = super().read(**params)
#      37 if result is None:
#      38     result = resp.json()
#
# File e:\아경\AI\Python38\lib\site-packages\pykrx\website\comm\webio.py:26, in Post.read(self, **params)
#      25 def read(self, **params):
# ---> 26     resp = requests.post(self.url, headers=self.headers, data=params)
#      27     return resp
#
# File e:\아경\AI\Python38\lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File e:\아경\AI\Python38\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File e:\아경\AI\Python38\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File e:\아경\AI\Python38\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File e:\아경\AI\Python38\lib\site-packages\requests\adapters.py:700, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     696     if isinstance(e.reason, _SSLError):
#     697         # This branch is for urllib3 v1.22 and later.
#     698         raise SSLError(e, request=request)
# --> 700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#     703     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPConnectionPool(host='data.krx.co.kr', port=80): Max retries exceeded with url: /comm/bldAttendant/getJsonData.cmd (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000021DEFA97220>: Failed to establish a new connection: [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다'))

# %% [markdown]
# # 주식 및 ETF 데이터 수집

# %%
# pip install beautifulsoup4 pandas openpyxl selenium webdriver-manager pykrx sqlalchemy pymysql

# %%
# pip install pymysql
# Out:
# Requirement already satisfied: pymysql in e:\아경\ai\python38\lib\site-packages (1.1.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 24.0 is available.
# You should consider upgrading via the 'e:\아경\AI\Python38\python.exe -m pip install --upgrade pip' command.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time
from pykrx import stock
import datetime
import os
from sqlalchemy import create_engine
import pymysql
import numpy as np
import configparser



# 설정 파일 읽기
config = configparser.ConfigParser()
config.read('config.ini')

username = config['mysql']['username']
password = config['mysql']['password']
host = config['mysql']['host']
database = config['mysql']['database']

conn = pymysql.connect(host=host, user=username, password=password, db=database, charset='utf8')
cur = conn.cursor()

# %%
# 테이블 생성 함수
def create_tables():
    cur.execute('''
    CREATE TABLE IF NOT EXISTS stock_data (
        ticker VARCHAR(10),
        name VARCHAR(100),
        date DATE,
        open FLOAT,
        high FLOAT,
        low FLOAT,
        close FLOAT,
        volume BIGINT,
        value BIGINT,
        market_cap BIGINT,
        shares_outstanding BIGINT,
        PER FLOAT,
        PBR FLOAT,
        dividend FLOAT,
        BPS FLOAT,
        EPS FLOAT,
        DPS FLOAT,
        normalized_value FLOAT,
        PRIMARY KEY (ticker, date)
    )
    ''')
    cur.execute('''
    CREATE TABLE IF NOT EXISTS ticker_list (
        ticker VARCHAR(10) PRIMARY KEY,
        market VARCHAR(10),
        name VARCHAR(100),
        last_updated DATE,
        is_delisted BOOLEAN DEFAULT FALSE
    )
    ''')
    cur.execute('''
    CREATE TABLE IF NOT EXISTS ticker_status (
        ticker VARCHAR(10) PRIMARY KEY,
        status VARCHAR(20)
    )
    ''')
create_tables()

# %%
# 모든 티커 리스트를 저장할 집합
all_tickers = set()

# 시작 날짜와 현재 날짜 설정
start_date = '19950102' # 이 시기부터 ticker list를 제공
end_date = datetime.datetime.now().strftime('%Y%m%d')

# 모든 날짜에 대해 티커 리스트 가져오기
current_date = datetime.datetime.strptime(start_date, '%Y%m%d')
while current_date.strftime('%Y%m%d') <= end_date:
    date_str = current_date.strftime('%Y%m%d')
    try:
        tickers_kosdaq = stock.get_market_ticker_list(date_str, market='KOSDAQ')
        tickers_kospi = stock.get_market_ticker_list(date_str, market='KOSPI')
        all_tickers.update(tickers_kosdaq)
        all_tickers.update(tickers_kospi)
        print(len(all_tickers),f'{date_str}')
        time.sleep(0.8)
    except Exception as e:
        print(f"Error on date {date_str}: {e}")
    current_date += datetime.timedelta(days=180)  # 180일 단위로 진행
    
# 티커 목록을 MySQL에 저장
for ticker in all_tickers:
    market = 'KOSDAQ' if ticker in tickers_kosdaq else 'KOSPI'
    name = stock.get_market_ticker_name(ticker)
    cur.execute('''
    INSERT INTO ticker_list (ticker, market, name) VALUES (%s, %s, %s)
    ON DUPLICATE KEY UPDATE market=VALUES(market), name=VALUES(name)
    ''', (ticker, market, name))
    # cur.execute('''
    # INSERT INTO ticker_status (ticker, status) VALUES (%s, 'pending')
    # ON DUPLICATE KEY UPDATE status=VALUES(status)
    # ''', (ticker,))  #1회 실행
    conn.commit()

cur.close()
conn.close()
print("모든 티커 목록이 성공적으로 저장되었습니다.")
# Out:
# 0 19950102
# 956 19950701
# 1132 19951228
# 1190 19960625
# 1758 19961222
# 1827 19970620
# 1906 19971217
# 1930 19980615
# 1941 19981212
# 2003 19990610
# 2117 19991207
# 2298 20000604
# 2440 20001201
# 2525 20010530
# 2638 20011126
# 2773 20020525
# 2848 20021121
# 2895 20030520
# 2944 20031116
# 2983 20040514
# 3016 20041110
# 3061 20050509
# 3121 20051105
# 3164 20060504
# 3214 20061031
# 3257 20070429
# 3322 20071026
# 3361 20080423
# 3404 20081020
# 3428 20090418
# 3467 20091015
# 3519 20100413
# 3571 20101010
# 3625 20110408
# 3664 20111005
# 3702 20120402
# 3720 20120929
# 3740 20130328
# 3758 20130924
# 3785 20140323
# 3807 20140919
# 3865 20150318
# 3932 20150914
# 4002 20160312
# 4034 20160908
# 4087 20170307
# 4137 20170903
# 4189 20180302
# 4227 20180829
# 4292 20190225
# 4338 20190824
# 4406 20200220
# 4450 20200818
# 4517 20210214
# 4573 20210813
# 4639 20220209
# 4693 20220808
# 4762 20230204
# 4832 20230803
# 4908 20240130
# 모든 티커 목록이 성공적으로 저장되었습니다.

# %% [markdown]
# ## Step 2: 데이터 갱신 및 새로운 티커 추가 (중단 후 재시작 가능)
# * 한번 실행한 경우 몇 거래일 뒤에 다시 실행해야 오류가 발생하지 않음

# %%
import datetime
import pymysql
import configparser
from pykrx import stock
import numpy as np

# 설정 파일 읽기
config = configparser.ConfigParser()
config.read('config.ini')

username = config['mysql']['username']
password = config['mysql']['password']
host = config['mysql']['host']
database = config['mysql']['database']

conn = pymysql.connect(host=host, user=username, password=password, db=database, charset='utf8')
cur = conn.cursor()

# 조건 설정
per_threshold = 10
pbr_threshold = 1
div_threshold = 3.5  # 기준금리 참조

# 현재 날짜 기준으로 최근 월 종목 리스트 수집
current_date = datetime.datetime.now()
last_month_str = current_date.strftime("%Y%m") + '01'

# 데이터베이스에서 모든 티커 가져오기
cur.execute("SELECT ticker FROM ticker_list")
all_tickers = [row[0] for row in cur.fetchall()]

# 각 티커에 대한 처리
for ticker in all_tickers:
    # 이미 처리된 티커는 스킵
    cur.execute(f"SELECT status FROM ticker_status WHERE ticker = '{ticker}'")
    status = cur.fetchone()
    if status and status[0] == 'completed':
        continue
    
     # 티커의 끝자리가 0이 아닌 경우 스킵
    if ticker[-1] != '0':
        print(f'{ticker} skipped because it does not end with 0')
        continue    
    
    # 데이터베이스에서 마지막 날짜 확인
    cur.execute(f"SELECT MAX(date) FROM stock_data WHERE ticker = '{ticker}'")
    last_date = cur.fetchone()[0]
    # 마지막 날짜가 현재 날짜와 7일 이하로 차이나는 경우 continue
    if last_date: # 이미 저장된 데이터가 있다면
        last_recorded_date = pd.to_datetime(last_date)
        if (current_date - last_recorded_date).days <= 7:
            print(f'{ticker} already done')
            continue
    # 새 데이터를 가져옴
    if last_date:
        start_date = (last_date + datetime.timedelta(days=1)).strftime("%Y%m%d")
    else:
        start_date = "19800102"

    end_date = current_date.strftime("%Y%m%d")
    time.sleep(3)
    df2 = stock.get_market_fundamental(start_date, end_date, ticker)


    if df2.empty or 'PER' not in df2.columns:
        cur.execute(f"UPDATE ticker_status SET status = 'completed' WHERE ticker = '{ticker}'")
        conn.commit()
        print(f'{ticker} no.2 pass condition')
        time.sleep(3)
        continue

    # 조건 확인
    if ('PER' in df2.columns and 'PBR' in df2.columns and 'DIV' in df2.columns):
        condition = (df2['PER'] > 0) & (df2['PER'] <= per_threshold) & \
                    (df2['PBR'] > 0) & (df2['PBR'] <= pbr_threshold) & \
                    (df2['DIV'] >= div_threshold)
        if not condition.any() and last_date is None:  #조건을 만족하지 않거나 새로운데이터가 없으면 해당 종목은 종료(completed)
            cur.execute(f"UPDATE ticker_status SET status = 'completed' WHERE ticker = '{ticker}'")
            conn.commit()
            print(f'{ticker} no.3 pass condition')
            time.sleep(8)  
            continue  # 조건을 만족하지 않으면 다음 티커로 넘어감
        
    else:
        cur.execute(f"UPDATE ticker_status SET status = 'completed' WHERE ticker = '{ticker}'")
        conn.commit()
        print(f'{ticker} no.4 pass condition')
        continue  # 필요한 컬럼이 없으면 넘어감
    # time.sleep(12)    
    df1 = stock.get_market_ohlcv(start_date, end_date, ticker)
    

    if df1.empty:
        cur.execute(f"UPDATE ticker_status SET status = 'completed' WHERE ticker = '{ticker}'")
        conn.commit()
        print(f'{ticker} no.5 pass condition')
        continue

    # '고가' 컬럼이 있는지 확인
    if '고가' not in df1.columns:
        cur.execute(f"UPDATE ticker_status SET status = 'completed' WHERE ticker = '{ticker}'")
        conn.commit()
        print(f'{ticker} no.6 pass condition')
        continue
    # time.sleep(10)   
    df3 = stock.get_market_cap(start_date, end_date, ticker)
    
    
    df1.reset_index(inplace=True)
    df2.reset_index(inplace=True)
    df3.reset_index(inplace=True)
    # 컬럼명 통일
    df1.rename(columns={
        '날짜': 'date',
        '시가': 'open',
        '고가': 'high',
        '저가': 'low',
        '종가': 'close',
        '거래량': 'volume',
        
    }, inplace=True)

    df2.rename(columns={
        '날짜': 'date',
        'PER': 'PER',
        'PBR': 'PBR',
        'DIV': 'dividend',
        'BPS': 'BPS',
        'EPS': 'EPS',
        'DPS': 'DPS'
    }, inplace=True)

    df3.rename(columns={
        '날짜': 'date',
        '시가총액': 'market_cap',
        '상장주식수': 'shares_outstanding',
        '거래대금': 'value',
        '거래량': 'volume'
        
    }, inplace=True)

    
     # 날짜 기준으로 결합하고 중복된 열 제거
    merged_df = pd.merge(df1, df2, on='date', how='outer', suffixes=('', '_duplicate'))
    merged_df = pd.merge(merged_df, df3, on='date', how='outer', suffixes=('', '_duplicate'))
    
    # 중복된 열 제거
    for column in merged_df.columns:
        if 'duplicate' in column:
            base_column = column.replace('_duplicate', '')
            if base_column in merged_df.columns:
                merged_df.drop(column, axis=1, inplace=True)
    
    # 필요한 열만 남기기
    merged_df = merged_df[['date', 'open', 'high', 'low', 'close', 'volume', 'value', 'market_cap', 'shares_outstanding', 'PER', 'PBR', 'dividend', 'BPS', 'EPS', 'DPS']]
    # merged_df 상태 출력
  
    # NaN 값을 None으로 변환 (개별적으로 처리)
    merged_df = merged_df.replace({np.nan: None})
    # # merged_df 상태 출력
    # print("merged_df:")
    # print(merged_df.head())
    
    name = stock.get_market_ticker_name(ticker)
    merged_df['ticker'] = ticker
    merged_df['name'] = name
  
    

    # 기존 데이터를 가져와서 새로운 데이터와 결합
    if last_date:
        cur.execute(f"SELECT * FROM stock_data WHERE ticker = '{ticker}' AND date <= '{last_date}'")
        existing_data = pd.DataFrame(cur.fetchall(), columns=['ticker', 'name', 'date', 'open', 'high', 'low', 'close', 'volume', 'value', 'market_cap', 'shares_outstanding', 'PER', 'PBR', 'dividend', 'BPS', 'EPS', 'DPS','normalized_value'])
        existing_data['date'] = pd.to_datetime(existing_data['date'])
        existing_data.set_index('date', inplace=True)
        
        combined_df = pd.concat([existing_data, merged_df], axis=0, join='outer')
          # 여기서 결합 전에 각 데이터프레임 확인

        
    else: # 기존데이터가 없으면 로드된 세 DF만 결합
        combined_df = merged_df
    # print(combined_df)
    
    
        # 'date'가 null인 행 찾기
    null_date_rows = combined_df[combined_df['date'].isnull()]

    # null_date_rows 출력
    print("Rows with null dates:")
    print(null_date_rows)


    print(combined_df.columns)
    # 노멀라이즈드 값 계산
    combined_df['normalized_value'] = (combined_df['close'] - combined_df['close'].rolling(window=252*5, min_periods=252).min()) / \
                                      (combined_df['close'].rolling(window=252*5, min_periods=252).max() - combined_df['close'].rolling(window=252*5, min_periods=252).min()) * 100

    combined_df.reset_index(inplace=True)
    
    combined_df = combined_df.replace({np.nan: None})
    

    # 데이터베이스에 저장
    for _, row in combined_df.iterrows():
        sql = '''
        INSERT INTO stock_data (ticker, name, date, open, high, low, close, volume, value, market_cap, shares_outstanding, PER, PBR, dividend, BPS, EPS, DPS, normalized_value)
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
        ON DUPLICATE KEY UPDATE
            open=VALUES(open),
            high=VALUES(high),
            low=VALUES(low),
            close=VALUES(close),
            volume=VALUES(volume),
            value=VALUES(value),
            market_cap=VALUES(market_cap),
            shares_outstanding=VALUES(shares_outstanding),
            PER=VALUES(PER),
            PBR=VALUES(PBR),
            dividend=VALUES(dividend),
            BPS=VALUES(BPS),
            EPS=VALUES(EPS),
            DPS=VALUES(DPS),
            normalized_value=VALUES(normalized_value)
        '''
        cur.execute(sql, (
            row['ticker'],
            row['name'],
            row['date'].strftime('%Y-%m-%d') if row['date'] else None,
            row['open'],
            row['high'],
            row['low'],
            row['close'],
            int(row['volume']) if row['volume'] is not None else None,
            int(row['value']) if row['value'] is not None else None,
            int(row['market_cap']) if row['market_cap'] is not None else None,
            int(row['shares_outstanding']) if row['shares_outstanding'] is not None else None,
            row['PER'],
            row['PBR'],
            row['dividend'],
            row['BPS'],
            row['EPS'],
            row['DPS'],
            row['normalized_value']
        ))

    conn.commit()
     # 최근 60일 동안 데이터가 있는지 확인
    last_recorded_date = pd.to_datetime(combined_df['date']).max()
    if (current_date - last_recorded_date).days > 60:
        print(current_date - last_recorded_date,current_date,last_recorded_date)
        cur.execute(f"UPDATE ticker_status SET status = 'completed' WHERE ticker = '{ticker}'")
        conn.commit()
    print(f"{ticker} 데이터베이스에 저장 완료")
    time.sleep(5)


cur.close()
conn.close()
print("모든 데이터가 성공적으로 저장되었습니다.")
# Out:
# Rows with null dates:
#             ticker  name     open     high      low    close     volume  \
# 1990-01-03  000020  동화약품  22500.0  22500.0  22500.0  22500.0       10.0
# 1990-01-04  000020  동화약품  22200.0  23500.0  22200.0  23000.0     7230.0
# 1990-01-05  000020  동화약품  22500.0  22800.0  22500.0  22500.0     1280.0
# 1990-01-06  000020  동화약품  22200.0  22200.0  22200.0  22200.0     1140.0
# 1990-01-08  000020  동화약품  22200.0  22700.0  22200.0  22700.0     2370.0
# ...            ...   ...      ...      ...      ...      ...        ...
# 2024-06-10  000020  동화약품   8080.0   8150.0   8070.0   8100.0   103598.0
# 2024-06-11  000020  동화약품   8150.0   8170.0   8030.0   8080.0   101717.0
# 2024-06-12  000020  동화약품   8080.0   8150.0   8080.0   8140.0    54413.0
# 2024-06-13  000020  동화약품   8150.0   8190.0   8100.0   8180.0    68414.0
# 2024-06-14  000020  동화약품   8260.0   9200.0   8070.0   8300.0  1822466.0
#
#                    value    market_cap  shares_outstanding   PER   PBR  \
# 1990-01-03           NaN           NaN                 NaN   NaN   NaN
# 1990-01-04           NaN           NaN                 NaN   NaN   NaN
# 1990-01-05           NaN           NaN                 NaN   NaN   NaN
# 1990-01-06           NaN           NaN                 NaN   NaN   NaN
# 1990-01-08           NaN           NaN                 NaN   NaN   NaN
# ...                  ...           ...                 ...   ...   ...
# 2024-06-10  8.384293e+08  2.262449e+11          27931470.0  8.17  0.60
# 2024-06-11  8.210433e+08  2.256863e+11          27931470.0  8.15  0.60
# 2024-06-12  4.420943e+08  2.273622e+11          27931470.0  8.21  0.61
# 2024-06-13  5.573658e+08  2.284794e+11          27931470.0  8.25  0.61
# 2024-06-14  1.583044e+10  2.318312e+11          27931470.0  8.38  0.62
#
#             dividend      BPS    EPS    DPS  normalized_value date
# 1990-01-03       NaN      NaN    NaN    NaN               NaN  NaT
# 1990-01-04       NaN      NaN    NaN    NaN               NaN  NaT
# 1990-01-05       NaN      NaN    NaN    NaN               NaN  NaT
# 1990-01-06       NaN      NaN    NaN    NaN               NaN  NaT
# 1990-01-08       NaN      NaN    NaN    NaN               NaN  NaT
# ...              ...      ...    ...    ...               ...  ...
# 2024-06-10      2.22  13413.0  991.0  180.0            12.305  NaT
# 2024-06-11      2.23  13413.0  991.0  180.0            12.226  NaT
# 2024-06-12      2.21  13413.0  991.0  180.0            12.463  NaT
# 2024-06-13      2.20  13413.0  991.0  180.0            12.621  NaT
# 2024-06-14      2.17  13413.0  991.0  180.0            13.095  NaT
#
# [8922 rows x 18 columns]
# Index(['ticker', 'name', 'open', 'high', 'low', 'close', 'volume', 'value',
#        'market_cap', 'shares_outstanding', 'PER', 'PBR', 'dividend', 'BPS',
#        'EPS', 'DPS', 'normalized_value', 'date'],
#       dtype='object')
# ---------------------------------------------------------------------------
#
# IntegrityError                            Traceback (most recent call last)
#
# Cell In[41], line 226
#
#     205 for _, row in combined_df.iterrows():
#
#     206     sql = '''
#
#     207     INSERT INTO stock_data (ticker, name, date, open, high, low, close, volume, value, market_cap, shares_outstanding, PER, PBR, dividend, BPS, EPS, DPS, normalized_value)
#
#     208     VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
#
#    (...)
#
#     224         normalized_value=VALUES(normalized_value)
#
#     225     '''
#
# --> 226     cur.execute(sql, (
#
#     227         row['ticker'],
#
#     228         row['name'],
#
#     229         row['date'].strftime('%Y-%m-%d') if row['date'] else None,
#
#     230         row['open'],
#
#     231         row['high'],
#
#     232         row['low'],
#
#     233         row['close'],
#
#     234         int(row['volume']) if row['volume'] is not None else None,
#
#     235         int(row['value']) if row['value'] is not None else None,
#
#     236         int(row['market_cap']) if row['market_cap'] is not None else None,
#
#     237         int(row['shares_outstanding']) if row['shares_outstanding'] is not None else None,
#
#     238         row['PER'],
#
#     239         row['PBR'],
#
#     240         row['dividend'],
#
#     241         row['BPS'],
#
#     242         row['EPS'],
#
#     243         row['DPS'],
#
#     244         row['normalized_value']
#
#     245     ))
#
#     247 conn.commit()
#
#     248  # 최근 60일 동안 데이터가 있는지 확인
#
#
#
# File e:\아경\AI\Python38\lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#
#     149     pass
#
#     151 query = self.mogrify(query, args)
#
# --> 153 result = self._query(query)
#
#     154 self._executed = query
#
#     155 return result
#
#
#
# File e:\아경\AI\Python38\lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#
#     320 conn = self._get_db()
#
#     321 self._clear_result()
#
# --> 322 conn.query(q)
#
#     323 self._do_get_result()
#
#     324 return self.rowcount
#
#
#
# File e:\아경\AI\Python38\lib\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
#
#     561     sql = sql.encode(self.encoding, "surrogateescape")
#
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
#
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#
#     564 return self._affected_rows
#
#
#
# File e:\아경\AI\Python38\lib\site-packages\pymysql\connections.py:825, in Connection._read_query_result(self, unbuffered)
#
#     823 else:
#
#     824     result = MySQLResult(self)
#
# --> 825     result.read()
#
#     826 self._result = result
#
#     827 if result.server_status is not None:
#
#
#
# File e:\아경\AI\Python38\lib\site-packages\pymysql\connections.py:1199, in MySQLResult.read(self)
#
#    1197 def read(self):
#
#    1198     try:
#
# -> 1199         first_packet = self.connection._read_packet()
#
#    1201         if first_packet.is_ok_packet():
#
#    1202             self._read_ok_packet(first_packet)
#
#
#
# File e:\아경\AI\Python38\lib\site-packages\pymysql\connections.py:775, in Connection._read_packet(self, packet_type)
#
#     773     if self._result is not None and self._result.unbuffered_active is True:
#
#     774         self._result.unbuffered_active = False
#
# --> 775     packet.raise_for_error()
#
#     776 return packet
#
#
#
# File e:\아경\AI\Python38\lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#
#     217 if DEBUG:
#
#     218     print("errno =", errno)
#
# --> 219 err.raise_mysql_exception(self._data)
#
#
#
# File e:\아경\AI\Python38\lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#
#     148 if errorclass is None:
#
#     149     errorclass = InternalError if errno < 1000 else OperationalError
#
# --> 150 raise errorclass(errno, errval)
#
#
#
# IntegrityError: (1048, "Column 'date' cannot be null")

# %% [markdown]
# ## ETF 이름 & 티커 리스트 생성

# %%
# 크롬 드라이버 설정
options = webdriver.ChromeOptions()
options.add_argument('headless')  # 브라우저 창을 띄우지 않음
options.add_argument('disable-gpu')  # GPU 가속 비활성화
options.add_argument('lang=ko_KR')  # 한국어 페이지

# 크롬 드라이버 초기화
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# %%
import pandas as pd
import pymysql
import configparser
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time

# 설정 파일 읽기
config = configparser.ConfigParser()
config.read('config.ini')

username = config['mysql']['username']
password = config['mysql']['password']
host = config['mysql']['host']
database = config['mysql']['database']

# MySQL 연결
conn = pymysql.connect(host=host, user=username, password=password, db=database, charset='utf8')
cur = conn.cursor()

# 크롬 드라이버 설정
options = webdriver.ChromeOptions()
options.add_argument('headless')  # 브라우저 창을 띄우지 않음
options.add_argument('disable-gpu')  # GPU 가속 비활성화
options.add_argument('lang=ko_KR')  # 한국어 페이지

# 크롬 드라이버 초기화
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
# URL에서 HTML 컨텐츠를 가져옴
url = 'https://finance.naver.com/sise/etf.naver'
driver.get(url)

# 종목명과 티커를 추출하여 리스트로 저장
etf_data = []
rows = driver.find_elements(By.CSS_SELECTOR, '#etfItemTable > tr')
for row in rows:
    name_col = row.find_elements(By.CSS_SELECTOR, 'td.ctg a')
    if name_col:
        name = name_col[0].text.strip()
        ticker = name_col[0].get_attribute('href').split('=')[-1]  # 종목명 링크에서 티커 추출
        etf_data.append([name, ticker])

# 드라이버 종료
driver.quit()

# DataFrame 생성
df = pd.DataFrame(etf_data, columns=['종목명', '티커'])

# DataFrame을 Excel 파일로 저장
excel_filename = 'etf_list.xlsx'
df.to_excel(excel_filename, index=False)
print(f"Excel 파일로 저장되었습니다: {excel_filename}")

# DataFrame을 MySQL에 저장
create_table_query = '''
CREATE TABLE IF NOT EXISTS etf_list (
    name VARCHAR(100),
    ticker VARCHAR(20),
    PRIMARY KEY (ticker)
)
'''
cur.execute(create_table_query)
conn.commit()

# MySQL에 데이터 삽입
for index, row in df.iterrows():
    insert_query = '''
    INSERT INTO etf_list (name, ticker) VALUES (%s, %s)
    ON DUPLICATE KEY UPDATE name=VALUES(name)
    '''
    cur.execute(insert_query, (row['종목명'], row['티커']))

conn.commit()
cur.close()
conn.close()
print("MySQL 데이터베이스에 저장되었습니다.")
# Out:
# Excel 파일로 저장되었습니다: etf_list.xlsx
# MySQL 데이터베이스에 저장되었습니다.

# %% [markdown]
# ## ETF 이름 & 티커 리스트 생성

# %%
# 크롬 드라이버 설정
options = webdriver.ChromeOptions()
options.add_argument('headless')  # 브라우저 창을 띄우지 않음
options.add_argument('disable-gpu')  # GPU 가속 비활성화
options.add_argument('lang=ko_KR')  # 한국어 페이지

# 크롬 드라이버 초기화
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# %%
import pandas as pd
import pymysql
import configparser
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time

# 설정 파일 읽기
config = configparser.ConfigParser()
config.read('config.ini')

username = config['mysql']['username']
password = config['mysql']['password']
host = config['mysql']['host']
database = config['mysql']['database']

# MySQL 연결
conn = pymysql.connect(host=host, user=username, password=password, db=database, charset='utf8')
cur = conn.cursor()

# 크롬 드라이버 설정
options = webdriver.ChromeOptions()
options.add_argument('headless')  # 브라우저 창을 띄우지 않음
options.add_argument('disable-gpu')  # GPU 가속 비활성화
options.add_argument('lang=ko_KR')  # 한국어 페이지

# 크롬 드라이버 초기화
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
# URL에서 HTML 컨텐츠를 가져옴
url = 'https://finance.naver.com/sise/etf.naver'
driver.get(url)

# 종목명과 티커를 추출하여 리스트로 저장
etf_data = []
rows = driver.find_elements(By.CSS_SELECTOR, '#etfItemTable > tr')
for row in rows:
    name_col = row.find_elements(By.CSS_SELECTOR, 'td.ctg a')
    if name_col:
        name = name_col[0].text.strip()
        ticker = name_col[0].get_attribute('href').split('=')[-1]  # 종목명 링크에서 티커 추출
        etf_data.append([name, ticker])

# 드라이버 종료
driver.quit()

# DataFrame 생성
df = pd.DataFrame(etf_data, columns=['종목명', '티커'])

# DataFrame을 Excel 파일로 저장
excel_filename = 'etf_list.xlsx'
df.to_excel(excel_filename, index=False)
print(f"Excel 파일로 저장되었습니다: {excel_filename}")

# DataFrame을 MySQL에 저장
create_table_query = '''
CREATE TABLE IF NOT EXISTS etf_list (
    name VARCHAR(100),
    ticker VARCHAR(20),
    PRIMARY KEY (ticker)
)
'''
cur.execute(create_table_query)
conn.commit()

# MySQL에 데이터 삽입
for index, row in df.iterrows():
    insert_query = '''
    INSERT INTO etf_list (name, ticker) VALUES (%s, %s)
    ON DUPLICATE KEY UPDATE name=VALUES(name)
    '''
    cur.execute(insert_query, (row['종목명'], row['티커']))

conn.commit()
cur.close()
conn.close()
print("MySQL 데이터베이스에 저장되었습니다.")
# Out:
# Excel 파일로 저장되었습니다: etf_list.xlsx
# MySQL 데이터베이스에 저장되었습니다.
